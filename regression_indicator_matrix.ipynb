# %%
from TP_knn.tp_knn_source import *

# %%
X, y = rand_tri_gauss(n1=100, n2=100, n3=100)
print(X)
# Out:
# [[-1.15399154 -0.91740231]
#  [ 1.00336474  0.85962944]
#  [-0.98303168 -1.10471749]
#  [ 1.09900483 -1.02272634]
#  [ 0.87675499  0.95011578]
#  [ 1.14680918 -1.00290323]
#  [-1.02932966 -1.07718359]
#  [ 0.93390414 -1.05060881]
#  [ 0.93675897  0.94219926]
#  [ 0.98956812  1.07733022]
#  [ 0.98679849  1.09896441]
#  [-1.07044599 -0.96944399]
#  [ 0.913339   -0.8575816 ]
#  [ 1.03572019  0.93334919]
#  [ 0.93287059 -1.06770463]
#  [-0.96835436 -0.929234  ]
#  [ 0.86696445 -0.83899891]
#  [ 0.92686198 -0.99120676]
#  [ 1.04443381  1.05894376]
#  [-0.96497276 -0.9764233 ]
#  [ 0.94407909 -0.95660798]
#  [ 1.09414269 -1.14497511]
#  [ 1.01208464 -0.87018627]
#  [ 1.14179482 -0.83323023]
#  [ 1.02876224  0.92487267]
#  [ 1.20683822  0.98198212]
#  [-1.10250572 -0.99528054]
#  [ 1.04478782  1.0418721 ]
#  [-0.85365187 -0.99127028]
#  [-0.8957575  -1.03103327]
#  [ 0.94712722 -0.97677911]
#  [ 1.10593483  0.971511  ]
#  [ 1.10038848  1.12561461]
#  [ 0.85613059 -0.92457971]
# ...

# %%
plt.figure(figsize=(10, 10))
plot_2d(X, y)

# %%
sns.lmplot(x=X, y=y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-8aa3f91cc7b7> in <module>
# ----> 1 sns.lmplot(x=X, y=y)
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     582     # Reduce the dataframe to only needed columns
# ...
